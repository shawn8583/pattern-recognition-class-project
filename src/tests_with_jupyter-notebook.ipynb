# %%
import pandas as pd

df = pd.read_csv('/home/shawn/projects/pattern_recognition_class_project/face/csv_eigenfaces/faceR_csv_test.csv')

# print(df.head(5))
df[['0', '1', '2']]
# Out:
#          0            1            2
# 0     1223 -1779.619019  2107.301270
# 1     1224 -2719.973389  2978.843750
# 2     1225  -946.141785 -1171.160278
# 3     1226   923.962097    -3.056940
# 4     1227  1747.073242  1018.751465
# 5     1228     0.000000     0.000000
# 6     1229 -1522.900513    36.874554
# 7     1230 -4058.238525   635.122925
# 8     1231   385.005646    -2.431623
# 9     1232 -1553.914429  3061.685059
# 10    1233  -310.221588  2732.313721
# 11    1234   250.836563  1529.763794
# 12    1235 -2228.739014  1366.159424
# 13    1236 -1059.949219  -984.592407
# 14    1237   -17.215994 -1803.705688
# 15    1238 -2061.523926 -1014.614014
# 16    1239 -3263.585205 -1395.698608
# 17    1240   321.765778    86.402847
# 18    1241 -1616.442261 -1561.523560
# 19    1242 -2859.647705  1132.630127
# 20    1243  -421.430725 -1931.747070
# 21    1244  1708.397339  1844.026733
# 22    1245 -1471.264282  1824.479614
# 23    1246 -1969.646729   864.023132
# ...
